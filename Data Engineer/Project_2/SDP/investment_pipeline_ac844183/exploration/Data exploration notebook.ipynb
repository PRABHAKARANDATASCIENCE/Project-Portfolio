-- %%
describe sdp_investment.bronze.holding_raw_sdp;

-- %%
select * from sdp_investment.bronze.holding_raw_sdp;

-- %%
create schema if not exists sdp_investment.silver;

-- %%
create schema if not exists sdp_investment.gold;

-- %%
select * from sdp_investment.gold.gold_porfolio_holdings;

-- %%
select sum(total_current_value) from sdp_investment.gold.gold_porfolio_holdings;

-- %%
select sum(total_current_value) from sdp_investment.gold.gold_porfolio_holdings;

-- %%
-- See the history of the source streaming table
DESCRIBE HISTORY sdp_investment.silver.holding_silver_sdp;

-- %%
select * from sdp_investment.gold.gold_porfolio_holdings;

-- %%
select * from sdp_investment.bronze.dividend_raw_sdp;

-- %%
describe sdp_investment.bronze.dividend_raw_sdp;

-- %%
select * from sdp_investment.silver.dividend_silver_sdp;

-- %%
select * from sdp_investment.silver.dividend_silver_sdp;

-- %%
select * from sdp_investment.gold.gold_dividend_by_stock;

-- %%
select * from sdp_investment.gold.gold_monthly_dividend;

-- %%
select * from sdp_investment.gold.gold_monthly_dividend
order by month;
