# %% [markdown]
# #staring the investment Project

# %%
df = spark.read.format("delta").load("/databricks-datasets/structured-streaming/events").withColumn("date", current_timestamp())
display(df)
df.writeStream.format("delta").option("checkpointLocation", "
