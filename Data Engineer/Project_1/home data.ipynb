# %%
# 1. Run the Bronze Layer Ingestion
print("Starting Bronze Layer Ingestion...")
dbutils.notebook.run("/Users/itcmark4@gmail.com/data_engineer_Project_1/Bronze_layer", 600)
# 2. Run the Silver Layer Cleaning & Transformation
print("Starting Silver Layer Transformation...")
dbutils.notebook.run("/Users/itcmark4@gmail.com/data_engineer_Project_1/Silver_layer",600)
# 3. Run the Gold Layer Business Aggregations
print("Starting Gold Layer Transformation...")
dbutils.notebook.run("/Users/itcmark4@gmail.com/data_engineer_Project_1/Gold_Layer",600)

print("All Layer executed successfully! End to End piplene completed")
# Out:
# Starting Bronze Layer Ingestion...
# Starting Silver Layer Transformation...
# Starting Gold Layer Transformation...
# All Layer executed successfully! End to End piplene completed
