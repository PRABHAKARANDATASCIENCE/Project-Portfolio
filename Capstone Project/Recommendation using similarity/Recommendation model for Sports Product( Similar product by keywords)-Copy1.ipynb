# %% [markdown]
# # Systematic Similarity

# %% [markdown]
# ## Data Preparation:
# - The code starts by importing necessary libraries and loading a cleaned dataset (t2.csv).
# - It defines functions to clean text data by removing punctuation and stopwords using NLTK.
# - The dataset is then sliced to a smaller size (df1) due to computational limitations.

# %%
import numpy as np   #for numerical calculation
import pandas as pd  #for data analysis

import string 
import regex # regular expression
from nltk.corpus import stopwords # to remove stopwords using nltk library

# %%
df=pd.read_csv('t2.csv') # reading the data which we cleaned before

# %%
df.info() # data information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2683 entries, 0 to 2682
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   2683 non-null   int64
#  1   category     2683 non-null   object
#  2   description  2683 non-null   object
#  3   title        2683 non-null   object
#  4   brand        2683 non-null   object
#  5   date         2683 non-null   object
#  6   price        2683 non-null   float64
#  7   asin         2683 non-null   object
#  8   imageURL     2683 non-null   object
#  9   overall      2683 non-null   int64
#  10  verified     2683 non-null   bool
#  11  reviewTime   2683 non-null   object
#  12  reviewText   2683 non-null   object
#  13  reviewerID   2683 non-null   object
#  14  Sentimental  2683 non-null   object
# dtypes: bool(1), float64(1), int64(2), object(11)
# memory usage: 296.2+ KB

# %%
df.isnull().sum() # finding null values
# Out:
# Unnamed: 0     0
# category       0
# description    0
# title          0
# brand          0
# date           0
# price          0
# asin           0
# imageURL       0
# overall        0
# verified       0
# reviewTime     0
# reviewText     0
# reviewerID     0
# Sentimental    0
# dtype: int64

# %%
df.head()
# Out:
#    Unnamed: 0                                           category  \
# 0         128  ['Sports & Outdoors', 'Outdoor Recreation', 'C...
# 1         129  ['Sports & Outdoors', 'Outdoor Recreation', 'C...
# 2         130  ['Sports & Outdoors', 'Outdoor Recreation', 'C...
# 3         131  ['Sports & Outdoors', 'Outdoor Recreation', 'C...
# 4         132  ['Sports & Outdoors', 'Outdoor Recreation', 'C...
#
#                                          description  \
# 0  ["Rely on delorme ATLAS & gazetteer paper maps...
# 1  ["Rely on delorme ATLAS & gazetteer paper maps...
# 2  ["Rely on delorme ATLAS & gazetteer paper maps...
# 3  ["Rely on delorme ATLAS & gazetteer paper maps...
# 4  ["Rely on delorme ATLAS & gazetteer paper maps...
#
#                                                title   brand        date  \
# 0  Garmin DeLorme Atlas &amp; Gazetteer Paper Map...  Garmin  2003-08-04
# 1  Garmin DeLorme Atlas &amp; Gazetteer Paper Map...  Garmin  2003-08-04
# 2  Garmin DeLorme Atlas &amp; Gazetteer Paper Map...  Garmin  2003-08-04
# 3  Garmin DeLorme Atlas &amp; Gazetteer Paper Map...  Garmin  2003-08-04
# 4  Garmin DeLorme Atlas &amp; Gazetteer Paper Map...  Garmin  2003-08-04
#
#    price        asin                                           imageURL  \
# 0  21.96  0899333257  ['https://images-na.ssl-images-amazon.com/imag...
# 1  21.96  0899333257  ['https://images-na.ssl-images-amazon.com/imag...
# 2  21.96  0899333257  ['https://images-na.ssl-images-amazon.com/imag...
# 3  21.96  0899333257  ['https://images-na.ssl-images-amazon.com/imag...
# 4  21.96  0899333257  ['https://images-na.ssl-images-amazon.com/imag...
#
#    overall  verified   reviewTime  \
# 0        5     False  01 25, 2008
# 1        3     False  10 28, 2007
# 2        5      True   05 7, 2007
# 3        5      True   04 3, 2007
# 4        5      True  02 15, 2007
#
#                                           reviewText      reviewerID  \
# 0  These Delorme Atlas & Gazetters are wondeful. ...  A2IUHI0QMEC9US
# 1  I purchased the maps so I could see the elevat...   APPM2Z3VPETEX
# 2  Great Product! Nearly as good as having a sepe...  A210MD07WALT56
# 3  I have nothing but praise for DeLorme.  We hav...  A2DTG02DSNOLQY
# 4  This is a must have for finding the tucked awa...  A1T4WK0L835QHQ
#
#   Sentimental
# 0    Positive
# 1     Neutral
# 2    Positive
# 3    Positive
# 4    Positive

# %%
df1=df[:10000] # slicing data because my pc doesnt support large data

# %% [markdown]
# ## Text Cleaning:
# - The product names, categories, and descriptions are cleaned using the defined text processing functions.
# - Cleaned text is converted back to strings and combined into a single column (combined_text) for each product.

# %%
def text_process(text): # cleaning the data
    nopunc = [char for char in  text if char not in string.punctuation]
    nopunc = ''.join(nopunc)
    return [word for word in nopunc.split() if word.lower() not in stopwords.words('english')]

# %%
def list_to_string(s): # converting list to string
    str1 = " "
    return (str1.join(s))

# %%
# cleaning the dataset
df1['Product_name']=df1['title'].apply(text_process)
df1['category_for_rec']=df1['category'].apply(text_process)
df1['description_for_rec']=df1['description'].apply(text_process)
# Out:
# C:\Users\prabh\AppData\Local\Temp\ipykernel_12908\939280148.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Product_name']=df1['title'].apply(text_process)
# C:\Users\prabh\AppData\Local\Temp\ipykernel_12908\939280148.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['category_for_rec']=df1['category'].apply(text_process)
# C:\Users\prabh\AppData\Local\Temp\ipykernel_12908\939280148.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['description_for_rec']=df1['description'].apply(text_process)

# %%
# converting data from list to string
df1['Product_name']=df1['Product_name'].apply(list_to_string)
df1['category_for_rec']=df1['category_for_rec'].apply(list_to_string)
df1['description_for_rec']=df1['description_for_rec'].apply(list_to_string)
# Out:
# C:\Users\prabh\AppData\Local\Temp\ipykernel_12908\1776642517.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Product_name']=df1['Product_name'].apply(list_to_string)
# C:\Users\prabh\AppData\Local\Temp\ipykernel_12908\1776642517.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['category_for_rec']=df1['category_for_rec'].apply(list_to_string)
# C:\Users\prabh\AppData\Local\Temp\ipykernel_12908\1776642517.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['description_for_rec']=df1['description_for_rec'].apply(list_to_string)

# %%
df1.head()
# Out:
#    Unnamed: 0                                           category  \
# 0         128  ['Sports & Outdoors', 'Outdoor Recreation', 'C...
# 1         129  ['Sports & Outdoors', 'Outdoor Recreation', 'C...
# 2         130  ['Sports & Outdoors', 'Outdoor Recreation', 'C...
# 3         131  ['Sports & Outdoors', 'Outdoor Recreation', 'C...
# 4         132  ['Sports & Outdoors', 'Outdoor Recreation', 'C...
#
#                                          description  \
# 0  ["Rely on delorme ATLAS & gazetteer paper maps...
# 1  ["Rely on delorme ATLAS & gazetteer paper maps...
# 2  ["Rely on delorme ATLAS & gazetteer paper maps...
# 3  ["Rely on delorme ATLAS & gazetteer paper maps...
# 4  ["Rely on delorme ATLAS & gazetteer paper maps...
#
#                                                title   brand        date  \
# 0  Garmin DeLorme Atlas &amp; Gazetteer Paper Map...  Garmin  2003-08-04
# 1  Garmin DeLorme Atlas &amp; Gazetteer Paper Map...  Garmin  2003-08-04
# 2  Garmin DeLorme Atlas &amp; Gazetteer Paper Map...  Garmin  2003-08-04
# 3  Garmin DeLorme Atlas &amp; Gazetteer Paper Map...  Garmin  2003-08-04
# 4  Garmin DeLorme Atlas &amp; Gazetteer Paper Map...  Garmin  2003-08-04
#
#    price        asin                                           imageURL  \
# 0  21.96  0899333257  ['https://images-na.ssl-images-amazon.com/imag...
# 1  21.96  0899333257  ['https://images-na.ssl-images-amazon.com/imag...
# 2  21.96  0899333257  ['https://images-na.ssl-images-amazon.com/imag...
# 3  21.96  0899333257  ['https://images-na.ssl-images-amazon.com/imag...
# 4  21.96  0899333257  ['https://images-na.ssl-images-amazon.com/imag...
#
#    overall  verified   reviewTime  \
# 0        5     False  01 25, 2008
# 1        3     False  10 28, 2007
# 2        5      True   05 7, 2007
# 3        5      True   04 3, 2007
# 4        5      True  02 15, 2007
#
#                                           reviewText      reviewerID  \
# 0  These Delorme Atlas & Gazetters are wondeful. ...  A2IUHI0QMEC9US
# 1  I purchased the maps so I could see the elevat...   APPM2Z3VPETEX
# 2  Great Product! Nearly as good as having a sepe...  A210MD07WALT56
# 3  I have nothing but praise for DeLorme.  We hav...  A2DTG02DSNOLQY
# 4  This is a must have for finding the tucked awa...  A1T4WK0L835QHQ
#
#   Sentimental                                       Product_name  \
# 0    Positive  Garmin DeLorme Atlas amp Gazetteer Paper Maps ...
# 1     Neutral  Garmin DeLorme Atlas amp Gazetteer Paper Maps ...
# 2    Positive  Garmin DeLorme Atlas amp Gazetteer Paper Maps ...
# 3    Positive  Garmin DeLorme Atlas amp Gazetteer Paper Maps ...
# 4    Positive  Garmin DeLorme Atlas amp Gazetteer Paper Maps ...
#
#                                     category_for_rec  \
# 0  Sports Outdoors Outdoor Recreation Camping Hik...
# 1  Sports Outdoors Outdoor Recreation Camping Hik...
# 2  Sports Outdoors Outdoor Recreation Camping Hik...
# 3  Sports Outdoors Outdoor Recreation Camping Hik...
# 4  Sports Outdoors Outdoor Recreation Camping Hik...
#
#                                  description_for_rec
# 0  Rely delorme ATLAS gazetteer paper maps utmost...
# 1  Rely delorme ATLAS gazetteer paper maps utmost...
# 2  Rely delorme ATLAS gazetteer paper maps utmost...
# 3  Rely delorme ATLAS gazetteer paper maps utmost...
# 4  Rely delorme ATLAS gazetteer paper maps utmost...

# %%
df1['combined_text']=df1['Product_name']+' '+df1['category_for_rec']+' '+df1['description_for_rec'] #combining both column
# Out:
# C:\Users\prabh\AppData\Local\Temp\ipykernel_12908\15092516.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['combined_text']=df1['Product_name']+' '+df1['category_for_rec']+' '+df1['description_for_rec'] #combining both column

# %%
df1.head()
# Out:
#    Unnamed: 0                                           category  \
# 0         128  ['Sports & Outdoors', 'Outdoor Recreation', 'C...
# 1         129  ['Sports & Outdoors', 'Outdoor Recreation', 'C...
# 2         130  ['Sports & Outdoors', 'Outdoor Recreation', 'C...
# 3         131  ['Sports & Outdoors', 'Outdoor Recreation', 'C...
# 4         132  ['Sports & Outdoors', 'Outdoor Recreation', 'C...
#
#                                          description  \
# 0  ["Rely on delorme ATLAS & gazetteer paper maps...
# 1  ["Rely on delorme ATLAS & gazetteer paper maps...
# 2  ["Rely on delorme ATLAS & gazetteer paper maps...
# 3  ["Rely on delorme ATLAS & gazetteer paper maps...
# 4  ["Rely on delorme ATLAS & gazetteer paper maps...
#
#                                                title   brand        date  \
# 0  Garmin DeLorme Atlas &amp; Gazetteer Paper Map...  Garmin  2003-08-04
# 1  Garmin DeLorme Atlas &amp; Gazetteer Paper Map...  Garmin  2003-08-04
# 2  Garmin DeLorme Atlas &amp; Gazetteer Paper Map...  Garmin  2003-08-04
# 3  Garmin DeLorme Atlas &amp; Gazetteer Paper Map...  Garmin  2003-08-04
# 4  Garmin DeLorme Atlas &amp; Gazetteer Paper Map...  Garmin  2003-08-04
#
#    price        asin                                           imageURL  \
# 0  21.96  0899333257  ['https://images-na.ssl-images-amazon.com/imag...
# 1  21.96  0899333257  ['https://images-na.ssl-images-amazon.com/imag...
# 2  21.96  0899333257  ['https://images-na.ssl-images-amazon.com/imag...
# 3  21.96  0899333257  ['https://images-na.ssl-images-amazon.com/imag...
# 4  21.96  0899333257  ['https://images-na.ssl-images-amazon.com/imag...
#
#    overall  verified   reviewTime  \
# 0        5     False  01 25, 2008
# 1        3     False  10 28, 2007
# 2        5      True   05 7, 2007
# 3        5      True   04 3, 2007
# 4        5      True  02 15, 2007
#
#                                           reviewText      reviewerID  \
# 0  These Delorme Atlas & Gazetters are wondeful. ...  A2IUHI0QMEC9US
# 1  I purchased the maps so I could see the elevat...   APPM2Z3VPETEX
# 2  Great Product! Nearly as good as having a sepe...  A210MD07WALT56
# 3  I have nothing but praise for DeLorme.  We hav...  A2DTG02DSNOLQY
# 4  This is a must have for finding the tucked awa...  A1T4WK0L835QHQ
#
#   Sentimental                                       Product_name  \
# 0    Positive  Garmin DeLorme Atlas amp Gazetteer Paper Maps ...
# 1     Neutral  Garmin DeLorme Atlas amp Gazetteer Paper Maps ...
# 2    Positive  Garmin DeLorme Atlas amp Gazetteer Paper Maps ...
# 3    Positive  Garmin DeLorme Atlas amp Gazetteer Paper Maps ...
# 4    Positive  Garmin DeLorme Atlas amp Gazetteer Paper Maps ...
#
#                                     category_for_rec  \
# 0  Sports Outdoors Outdoor Recreation Camping Hik...
# 1  Sports Outdoors Outdoor Recreation Camping Hik...
# 2  Sports Outdoors Outdoor Recreation Camping Hik...
# 3  Sports Outdoors Outdoor Recreation Camping Hik...
# 4  Sports Outdoors Outdoor Recreation Camping Hik...
#
#                                  description_for_rec  \
# 0  Rely delorme ATLAS gazetteer paper maps utmost...
# 1  Rely delorme ATLAS gazetteer paper maps utmost...
# 2  Rely delorme ATLAS gazetteer paper maps utmost...
# 3  Rely delorme ATLAS gazetteer paper maps utmost...
# 4  Rely delorme ATLAS gazetteer paper maps utmost...
#
#                                        combined_text
# 0  Garmin DeLorme Atlas amp Gazetteer Paper Maps ...
# 1  Garmin DeLorme Atlas amp Gazetteer Paper Maps ...
# 2  Garmin DeLorme Atlas amp Gazetteer Paper Maps ...
# 3  Garmin DeLorme Atlas amp Gazetteer Paper Maps ...
# 4  Garmin DeLorme Atlas amp Gazetteer Paper Maps ...

# %%
df2=df1[['Product_name','category_for_rec','description_for_rec','combined_text']] # taking only required column for further anlaysis

# %%
df2.combined_text[0]
# Out:
# 'Garmin DeLorme Atlas amp Gazetteer Paper Maps Arizona AA000005000 Sports Outdoors Outdoor Recreation Camping Hiking Navigation Electronics Topographic Maps Rely delorme ATLAS gazetteer paper maps utmost trip Planning backcountry access available paperback 11inches x 155Inches 50 States'

# %%
#pip install sentence-transformers

# %% [markdown]
# ## Sentence Embedding:
# - Hugging Face's Sentence Transformers library is used to load a pre-trained model (all-MiniLM-L6-v2).
# - Each combined text is encoded into a vector representation using the pre-trained model, resulting in combined_embedding.

# %%
from sentence_transformers import SentenceTransformer # sentence tranformer

# %%
model = SentenceTransformer('all-MiniLM-L6-v2') # one of model from hugging face

# %% [markdown]
# # Embedding

# %%
df2['combined_embedding']=df2['combined_text'].apply(lambda x:model.encode(x)) # encoding the text to vector
# Out:
# C:\Users\prabh\AppData\Local\Temp\ipykernel_12908\4155631282.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['combined_embedding']=df2['combined_text'].apply(lambda x:model.encode(x)) # encoding the text to vector

# %%
df2.sample(20)
# Out:
#                                            Product_name  \
# 1186  Intex Explorer 200 2Person Inflatable Boat Set...
# 478   SOG Multitool Pliers Pocket Tool ndash ldquoPo...
# 292                   Case Black Ridgeback Hunter Knife
# 2226  Intex Explorer 200 2Person Inflatable Boat Set...
# 1639  Intex Explorer 200 2Person Inflatable Boat Set...
# 107   Garmin DeLorme Atlas amp Gazetteer Paper Maps ...
#
garmin DeLorme Atlas amp Gazetteer Paper Maps ...
# 1404  Intex Explorer 200 2Person Inflatable Boat Set...
# 495   SOG Multitool Pliers Pocket Tool ndash ldquoPo...
# 2355  Intex Explorer 200 2Person Inflatable Boat Set...
# 29    Garmin DeLorme Atlas amp Gazetteer Paper Maps ...
# 561   Intex Explorer 100 1Person Inflatable Boat Spo...
# 2575  Intex Explorer 200 2Person Inflatable Boat Set...
# 1286  Intex Explorer 200 2Person Inflatable Boat Set...
# 1755  Intex Explorer 200 2Person Inflatable Boat Set...
# 829   Intex Explorer 100 1Person Inflatable Boat Spo...
# 1321  Intex Explorer 200 2Person Inflatable Boat Set...
# 740   Intex Explorer 100 1Person Inflatable Boat Spo...
# 1998  Intex Explorer 200 2Person Inflatable Boat Set...
# 354   Case Black Ridgeback Hunter Knife Sports Outdo...
# 207   Case Amber Bone CV Canoe Pocket Knife Sports O...
#
#                                      combined_embedding
# 1186  [-0.0050696256, -0.062518805, 0.021104803, 0.0...
# 478   [-0.07354514, -0.03458747, -0.039415684, -0.04...
# 292   [-0.06744544, -0.006403379, -0.021779224, 0.00...
# 2226  [-0.0050696256, -0.062518805, 0.021104803, 0.0...
# 1639  [-0.0050696256, -0.062518805, 0.021104803, 0.0...
# 107   [-0.0075754165, -0.0015259096, -0.023112586, 0...
# 1404  [-0.0050696256, -0.062518805, 0.021104803, 0.0...
# 495   [-0.07354514, -0.03458747, -0.039415684, -0.04...
# 2355  [-0.0050696256, -0.062518805, 0.021104803, 0.0...
# 29    [-0.0075754165, -0.0015259096, -0.023112586, 0...
# 561   [0.0025712259, -0.02957016, -0.0036867904, 0.0...
# 2575  [-0.0050696256, -0.062518805, 0.021104803, 0.0...
# 1286  [-0.0050696256, -0.062518805, 0.021104803, 0.0...
# 1755  [-0.0050696256, -0.062518805, 0.021104803, 0.0...
# 829   [0.0025712259, -0.02957016, -0.0036867904, 0.0...
# 1321  [-0.0050696256, -0.062518805, 0.021104803, 0.0...
# 740   [0.0025712259, -0.02957016, -0.0036867904, 0.0...
# 1998  [-0.0050696256, -0.062518805, 0.021104803, 0.0...
# 354   [-0.06744544, -0.006403379, -0.021779224, 0.00...
# 207   [-0.10170844, 0.007938084, 0.014537651, 0.0167...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2683 entries, 0 to 2682
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Product_name         2683 non-null   object
#  1   category_for_rec     2683 non-null   object
#  2   description_for_rec  2683 non-null   object
#  3   combined_text        2683 non-null   object
#  4   combined_embedding   2683 non-null   object
# dtypes: object(5)
# memory usage: 104.9+ KB

# %%
df2.combined_embedding[0]
# Out:
# array([-7.57541647e-03, -1.52590964e-03, -2.31125858e-02,  2.05572005e-02,
#        -1.74666988e-03, -9.97751858e-03,  2.38002557e-02, -4.12319638e-02,
#        -6.25356361e-02,  1.97021253e-02, -1.22488877e-02,  4.10493900e-04,
#         7.93758184e-02,  1.02800932e-02,  1.20936586e-02, -1.01885740e-02,
#        -4.06932272e-02,  3.04490384e-02,  2.67656073e-02, -3.08387000e-02,
#         1.89062543e-02,  8.22362229e-02, -2.40688194e-02,  4.74595204e-02,
#        -3.99705302e-03,  3.45882103e-02,  1.56669831e-03,  2.29063630e-02,
#        -7.30910376e-02, -2.73126140e-02, -1.75094530e-02,  2.77200826e-02,
#         4.41192463e-02, -5.23010828e-03,  4.37136963e-02, -9.90534201e-03,
#        -2.77040303e-02, -2.89203003e-02, -2.26457808e-02, -2.78614424e-02,
#        -1.98608655e-02, -3.91041562e-02,  1.10147186e-02,  7.66877756e-02,
#         1.37882605e-02, -1.65927820e-02, -4.80582006e-02, -1.66058987e-02,
#         4.92002219e-02, -4.40760627e-02, -3.49128619e-03,  2.68599149e-02,
#         1.08979084e-02, -4.19425517e-02,  3.88682298e-02, -1.55823790e-02,
#         2.28671357e-02,  8.20405781e-02, -1.46784773e-02,  3.83133441e-02,
#         1.34476600e-02,  2.35755332e-02,  1.30583914e-02, -8.54332838e-03,
#        -4.70370054e-02, -4.98817973e-02,  4.03906554e-02, -1.28731266e-01,
#         6.93001896e-02, -2.58059595e-02, -6.79662898e-02, -7.43079260e-02,
#         4.36073989e-02,  4.12927866e-02,  6.98887333e-02,  3.03215235e-02,
#        -1.88008957e-02, -7.84102306e-02,  1.98347531e-02,  4.62940075e-02,
#         8.54059961e-03, -8.12372845e-03, -1.29221439e-01, -8.36119503e-02],
#       dtype=float32)

# %%
#df2.to_csv('data_with_embeddings.csv',index=False)

# %% [markdown]
# # Cosine Similarity
# - Cosine similarity is calculated between the input text and the embeddings of all products in the dataset.
# - The most similar products are identified based on the cosine similarity scores.
# - The top similar products are retrieved and displayed.

# %%
from sentence_transformers import util # cosine similarity

# %%
def get_similar_products(combined_input, df, top_n=1):
    combined_embedding = model.encode(combined_input)
    
    similarities = util.pytorch_cos_sim(combined_embedding, df2['combined_embedding'])
    
    print(similarities)
    
    similar_indices = similarities.argsort(descending= True,axis = 1)[0][:top_n]
    print(similar_indices)
    
    similar_items_df = df2.iloc[similar_indices][['Product_name','category_for_rec','description_for_rec']]
    #print(similar_items)
    return similar_items_df

# %%
product_info_to_search = "Colorful Chalkboard"

similar_items = get_similar_products(product_info_to_search,df2)
similar_items
# Out:
# tensor([[0.0721, 0.0721, 0.0721,  ..., 0.0148, 0.0148, 0.0148]])
# tensor([150])
#                                           Product_name  \
# 150  ZENY 15quotx30ft Battle Rope Workout Training ...
#
#                                     category_for_rec  \
# 150  Sports Outdoors Sports Fitness Exercise Fitness
#
#                                    description_for_rec
# 150  Practice Level Guide br Levels Sizes Rope br J...

# %%
print(product_info_to_search)
print("\nSimilar Products:")
for idx,row in similar_items.iterrows():
    print(f"Product : {row['Product_name']}")
# Out:
# Colorful Chalkboard
#
# Similar Products:
# Product : ZENY 15quotx30ft Battle Rope Workout Training Undulation Rope Fitness Rope Exercise

# %%
product_info_to_search = input("Enter Keywords : ")

similar_items = get_similar_products(product_info_to_search,df2)
print(product_info_to_search)
print("\nSimilar Products:")
for idx,row in similar_items.iterrows():
    print(f"Product : {row['Product_name']}")
similar_items
# Out:
# Enter Keywords : BAT
# tensor([[0.1312, 0.1312, 0.1312,  ..., 0.0733, 0.0733, 0.0733]])
# tensor([1022])
# BAT
#
# Similar Products:
# Product : Vaughan RB 28Ounce Rig Builders Hatchet Hickory Handle heavy construction 17Inch Long
#                                            Product_name  \
# 1022  Vaughan RB 28Ounce Rig Builders Hatchet Hickor...
#
#                                        category_for_rec  \
# 1022  Sports Outdoors Outdoor Recreation Camping Hik...
#
#                                     description_for_rec
# 1022  Forged American made high carbon steel fully p...

# %% [markdown]
# **This project aims to provide users with personalized and relevant product recommendations based on textual input, thereby enhancing their shopping experience and increasing engagement with the platform.**
