# %% [markdown]
# # Systematic Similarity

# %% [markdown]
# ## Data Preparation:
# - The code starts by importing necessary libraries and loading a cleaned dataset (t2.csv).
# - It defines functions to clean text data by removing punctuation and stopwords using NLTK.
# - The dataset is then sliced to a smaller size (df1) due to computational limitations.

# %%
import numpy as np   #for numerical calculation
import pandas as pd  #for data analysis

import string 
import regex # regular expression
from nltk.corpus import stopwords # to remove stopwords using nltk library

# %%
df=pd.read_csv('t1.csv') # reading the data which we cleaned before

# %%
df.info() # data information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33573 entries, 0 to 33572
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   33573 non-null  int64
#  1   category     33573 non-null  object
#  2   description  33573 non-null  object
#  3   title        33573 non-null  object
#  4   brand        33573 non-null  object
#  5   date         33573 non-null  object
#  6   price        33573 non-null  float64
#  7   asin         33573 non-null  object
#  8   imageURL     33573 non-null  object
#  9   overall      33573 non-null  int64
#  10  verified     33573 non-null  bool
#  11  reviewTime   33573 non-null  object
#  12  reviewText   33573 non-null  object
#  13  reviewerID   33573 non-null  object
#  14  Sentimental  33573 non-null  object
# dtypes: bool(1), float64(1), int64(2), object(11)
# memory usage: 3.6+ MB

# %%
df.isnull().sum() # finding null values
# Out:
# Unnamed: 0     0
# category       0
# description    0
# title          0
# brand          0
# date           0
# price          0
# asin           0
# imageURL       0
# overall        0
# verified       0
# reviewTime     0
# reviewText     0
# reviewerID     0
# Sentimental    0
# dtype: int64

# %%
df.head()
# Out:
#    Unnamed: 0                                           category  \
# 0           0  ['Office Products', 'Office & School Supplies'...
# 1           1  ['Office Products', 'Office & School Supplies'...
# 2           2  ['Office Products', 'Office & School Supplies'...
# 3           3  ['Office Products', 'Office & School Supplies'...
# 4           4  ['Office Products', 'Office & School Supplies'...
#
#                                          description                  title  \
# 0  ['Corduroy the bear goes to the launderette wi...  A Pocket for Corduroy
# 1  ['Corduroy the bear goes to the launderette wi...  A Pocket for Corduroy
# 2  ['Corduroy the bear goes to the launderette wi...  A Pocket for Corduroy
# 3  ['Corduroy the bear goes to the launderette wi...  A Pocket for Corduroy
# 4  ['Corduroy the bear goes to the launderette wi...  A Pocket for Corduroy
#
#                        brand        date  price        asin imageURL  overall  \
# 0  Ingram Book & Distributor  2006-09-14   0.95  0140503528       []        3
# 1  Ingram Book & Distributor  2006-09-14   0.95  0140503528       []        5
# 2  Ingram Book & Distributor  2006-09-14   0.95  0140503528       []        5
# 3  Ingram Book & Distributor  2006-09-14   0.95  0140503528       []        5
# 4  Ingram Book & Distributor  2006-09-14   0.95  0140503528       []        5
#
#    verified   reviewTime                                         reviewText  \
# 0     False   11 3, 2006  I thought the book was entertaining and cute, ...
# 1     False   05 9, 2006  This adorable story is an all time favorite fa...
# 2     False  03 11, 2006  Lisa's bear Corduroy gets lost in the laundrom...
# 3     False  01 24, 2001  In this installment of Corduroy's adventures w...
# 4     False  07 30, 2000  Researchers constantly find that reading to ch...
#
#        reviewerID Sentimental
# 0  A2WJLOXXIB7NF3     Neutral
# 1  A1RKICUK0GG6VF    Positive
# 2  A1QA5E50M398VW    Positive
# 3  A3N0HBW8IP8CZQ    Positive
# 4  A1K1JW1C5CUSUZ    Positive

# %%
df1=df[:10000] # slicing data because my pc doesnt support large data

# %% [markdown]
# ## Text Cleaning:
# - The product names, categories, and descriptions are cleaned using the defined text processing functions.
# - Cleaned text is converted back to strings and combined into a single column (combined_text) for each product.

# %%
def text_process(text): # cleaning the data
    nopunc = [char for char in  text if char not in string.punctuation]
    nopunc = ''.join(nopunc)
    return [word for word in nopunc.split() if word.lower() not in stopwords.words('english')]

# %%
def list_to_string(s): # converting list to string
    str1 = " "
    return (str1.join(s))

# %%
# cleaning the dataset
df1['Product_name']=df1['title'].apply(text_process)
df1['category_for_rec']=df1['category'].apply(text_process)
df1['description_for_rec']=df1['description'].apply(text_process)
# Out:
# C:\Users\prabh\AppData\Local\Temp\ipykernel_8736\939280148.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Product_name']=df1['title'].apply(text_process)
# C:\Users\prabh\AppData\Local\Temp\ipykernel_8736\939280148.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['category_for_rec']=df1['category'].apply(text_process)
# C:\Users\prabh\AppData\Local\Temp\ipykernel_8736\939280148.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['description_for_rec']=df1['description'].apply(text_process)

# %%
# converting data from list to string
df1['Product_name']=df1['Product_name'].apply(list_to_string)
df1['category_for_rec']=df1['category_for_rec'].apply(list_to_string)
df1['description_for_rec']=df1['description_for_rec'].apply(list_to_string)
# Out:
# C:\Users\prabh\AppData\Local\Temp\ipykernel_8736\1776642517.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Product_name']=df1['Product_name'].apply(list_to_string)
# C:\Users\prabh\AppData\Local\Temp\ipykernel_8736\1776642517.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['category_for_rec']=df1['category_for_rec'].apply(list_to_string)
# C:\Users\prabh\AppData\Local\Temp\ipykernel_8736\1776642517.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['description_for_rec']=df1['description_for_rec'].apply(list_to_string)

# %%
df1.head()
# Out:
#    Unnamed: 0                                           category  \
# 0           0  ['Office Products', 'Office & School Supplies'...
# 1           1  ['Office Products', 'Office & School Supplies'...
# 2           2  ['Office Products', 'Office & School Supplies'...
# 3           3  ['Office Products', 'Office & School Supplies'...
# 4           4  ['Office Products', 'Office & School Supplies'...
#
#                                          description                  title  \
# 0  ['Corduroy the bear goes to the launderette wi...  A Pocket for Corduroy
# 1  ['Corduroy the bear goes to the launderette wi...  A Pocket for Corduroy
# 2  ['Corduroy the bear goes to the launderette wi...  A Pocket for Corduroy
# 3  ['Corduroy the bear goes to the launderette wi...  A Pocket for Corduroy
# 4  ['Corduroy the bear goes to the launderette wi...  A Pocket for Corduroy
#
#                        brand        date  price        asin imageURL  overall  \
# 0  Ingram Book & Distributor  2006-09-14   0.95  0140503528       []        3
# 1  Ingram Book & Distributor  2006-09-14   0.95  0140503528       []        5
# 2  Ingram Book & Distributor  2006-09-14   0.95  0140503528       []        5
# 3  Ingram Book & Distributor  2006-09-14   0.95  0140503528       []        5
# 4  Ingram Book & Distributor  2006-09-14   0.95  0140503528       []        5
#
#    verified   reviewTime                                         reviewText  \
# 0     False   11 3, 2006  I thought the book was entertaining and cute, ...
# 1     False   05 9, 2006  This adorable story is an all time favorite fa...
# 2     False  03 11, 2006  Lisa's bear Corduroy gets lost in the laundrom...
# 3     False  01 24, 2001  In this installment of Corduroy's adventures w...
# 4     False  07 30, 2000  Researchers constantly find that reading to ch...
#
#        reviewerID Sentimental     Product_name  \
# 0  A2WJLOXXIB7NF3     Neutral  Pocket Corduroy
# 1  A1RKICUK0GG6VF    Positive  Pocket Corduroy
# 2  A1QA5E50M398VW    Positive  Pocket Corduroy
# 3  A3N0HBW8IP8CZQ    Positive  Pocket Corduroy
# 4  A1K1JW1C5CUSUZ    Positive  Pocket Corduroy
#
#                                     category_for_rec  \
# 0  Office Products Office School Supplies Educati...
# 1  Office Products Office School Supplies Educati...
# 2  Office Products Office School Supplies Educati...
# 3  Office Products Office School Supplies Educati...
# 4  Office Products Office School Supplies Educati...
#
#                                  description_for_rec
# 0  Corduroy bear goes launderette Lisa overhears ...
# 1  Corduroy bear goes launderette Lisa overhears ...
# 2  Corduroy bear goes launderette Lisa overhears ...
# 3  Corduroy bear goes launderette Lisa overhears ...
# 4  Corduroy bear goes launderette Lisa overhears ...

# %%
df1['combined_text']=df1['Product_name']+' '+df1['category_for_rec']+' '+df1['description_for_rec'] #combining both column
# Out:
# C:\Users\prabh\AppData\Local\Temp\ipykernel_8736\15092516.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['combined_text']=df1['Product_name']+' '+df1['category_for_rec']+' '+df1['description_for_rec'] #combining both column

# %%
df1.head()
# Out:
#    Unnamed: 0                                           category  \
# 0           0  ['Office Products', 'Office & School Supplies'...
# 1           1  ['Office Products', 'Office & School Supplies'...
# 2           2  ['Office Products', 'Office & School Supplies'...
# 3           3  ['Office Products', 'Office & School Supplies'...
# 4           4  ['Office Products', 'Office & School Supplies'...
#
#                                          description                  title  \
# 0  ['Corduroy the bear goes to the launderette wi...  A Pocket for Corduroy
# 1  ['Corduroy the bear goes to the launderette wi...  A Pocket for Corduroy
# 2  ['Corduroy the bear goes to the launderette wi...  A Pocket for Corduroy
# 3  ['Corduroy the bear goes to the launderette wi...  A Pocket for Corduroy
# 4  ['Corduroy the bear goes to the launderette wi...  A Pocket for Corduroy
#
#                        brand        date  price        asin imageURL  overall  \
# 0  Ingram Book & Distributor  2006-09-14   0.95  0140503528       []        3
# 1  Ingram Book & Distributor  2006-09-14   0.95  0140503528       []        5
# 2  Ingram Book & Distributor  2006-09-14   0.95  0140503528       []        5
# 3  Ingram Book & Distributor  2006-09-14   0.95  0140503528       []        5
# 4  Ingram Book & Distributor  2006-09-14   0.95  0140503528       []        5
#
#    verified   reviewTime                                         reviewText  \
# 0     False   11 3, 2006  I thought the book was entertaining and cute, ...
# 1     False   05 9, 2006  This adorable story is an all time favorite fa...
# 2     False  03 11, 2006  Lisa's bear Corduroy gets lost in the laundrom...
# 3     False  01 24, 2001  In this installment of Corduroy's adventures w...
# 4     False  07 30, 2000  Researchers constantly find that reading to ch...
#
#        reviewerID Sentimental     Product_name  \
# 0  A2WJLOXXIB7NF3     Neutral  Pocket Corduroy
# 1  A1RKICUK0GG6VF    Positive  Pocket Corduroy
# 2  A1QA5E50M398VW    Positive  Pocket Corduroy
# 3  A3N0HBW8IP8CZQ    Positive  Pocket Corduroy
# 4  A1K1JW1C5CUSUZ    Positive  Pocket Corduroy
#
#                                     category_for_rec  \
# 0  Office Products Office School Supplies Educati...
# 1  Office Products Office School Supplies Educati...
# 2  Office Products Office School Supplies Educati...
# 3  Office Products Office School Supplies Educati...
# 4  Office Products Office School Supplies Educati...
#
#                                  description_for_rec  \
# 0  Corduroy bear goes launderette Lisa overhears ...
# 1  Corduroy bear goes launderette Lisa overhears ...
# 2  Corduroy bear goes launderette Lisa overhears ...
# 3  Corduroy bear goes launderette Lisa overhears ...
# 4  Corduroy bear goes launderette Lisa overhears ...
#
#                                        combined_text
# 0  Pocket Corduroy Office Products Office School ...
# 1  Pocket Corduroy Office Products Office School ...
# 2  Pocket Corduroy Office Products Office School ...
# 3  Pocket Corduroy Office Products Office School ...
# 4  Pocket Corduroy Office Products Office School ...

# %%
df2=df1[['Product_name','category_for_rec','description_for_rec','combined_text']] # taking only required column for further anlaysis

# %%
df2.combined_text[0]
# Out:
# 'Pocket Corduroy Office Products Office School Supplies Education Crafts Early Childhood Education Materials Corduroy bear goes launderette Lisa overhears mother warn taking things pockets washing clothes Corduroy discovers pocket begins search find one'

# %%
#pip install sentence-transformers

# %% [markdown]
# ## Sentence Embedding:
# - Hugging Face's Sentence Transformers library is used to load a pre-trained model (all-MiniLM-L6-v2).
# - Each combined text is encoded into a vector representation using the pre-trained model, resulting in combined_embedding.

# %%
from sentence_transformers import SentenceTransformer # sentence tranformer

# %%
model = SentenceTransformer('all-MiniLM-L6-v2') # one of model from hugging face

# %% [markdown]
# # Embedding

# %%
df2['combined_embedding']=df2['combined_text'].apply(lambda x:model.encode(x)) # encoding the text to vector
# Out:
# C:\Users\prabh\AppData\Local\Temp\ipykernel_8736\4155631282.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['combined_embedding']=df2['combined_text'].apply(lambda x:model.encode(x)) # encoding the text to vector

# %%
df2.sample(20)
# Out:
#                                            Product_name  \
# 1868  Scholastic Teachers Friend Schedule Cards Pock...
# 1340      Scholastic File Organizer Pocket Chart TF5104
# 3119  Carson Dellosa 5239 KidDrawn Christian Faith S...
# 3395  MarkMyTime Digital Bookmark Reading Timer Neon...
# 5451  Freedom Journal Best Daily Planner Accomplish ...
# 7059               CarsonDellosa File Folders CDP136002
# 1550                              Standard Pocket Chart
# 4377  pretty simple cards quotThank Cardsquot 12 Car...
# 5113  Freedom Journal Best Daily Planner Accomplish ...
# 1706  Scholastic Primary Math Charts Bulletin Board ...
# 3916  Neck Traction Collar Men Women Cervical Brace ...
# 9643             Knock Knock Love Mom Fill Love Journal
# 1112  Rand McNally MSeries FullColor Laminated Unite...
# 9398             Knock Knock Love Mom Fill Love Journal
# 1958  Scholastic Classroom Resources File Organizer ...
# 5286  Freedom Journal Best Daily Planner Accomplish ...
# 8323                                Knock Knock Pad Red
# 5919  OOLY Yummy Yummy Scented Glitter Gel Pens 1321...
# 4759  Productivity Planner Daily Planner Non Dated 5...
# 9124               Knock Knock High Five Nifty Note Pad
#
#                                        category_for_rec  \
# 1868  Office Products Office amp School Supplies Edu...
# 1340  Office Products Office amp School Supplies Edu...
# 3119  Office Products Office amp School Supplies Edu...
# 3395  Office Products Office amp School Supplies Boo...
# 5451  Office Products Office amp School Supplies Cal...
# 7059  Office Products Office School Supplies Filing ...
# 1550  Office Products Office amp School Supplies Edu...
# 4377  Office Products Office School Supplies Paper C...
# 5113  Office Products Office amp School Supplies Cal...
# 1706
# 3916  Office Products Office amp School Supplies Cal...
# 9643   Office Products Office amp School Supplies Paper
# 1112  Office Products Office amp School Supplies Edu...
# 9398   Office Products Office amp School Supplies Paper
# 1958  Office Products Office amp School Supplies Edu...
# 5286  Office Products Office amp School Supplies Cal...
# 8323  Office Products Office amp School Supplies Pap...
# 5919  Office Products Office amp School Supplies Wri...
# 4759  Office Products Office amp School Supplies Cal...
# 9124  Office Products Office School Supplies Paper N...
#
#                                     description_for_rec  \
# 1868         use Scholastic Daily Schedule Pocket Chart
# 1340  Pocket chart features 10 sturdy pockets fit le...
# 3119  Perfect reward recognition pack acidfree ligni...
# 3395  bTheres product quite like accurately track ch...
# 5451
# 7059  Make organizing fun cool bubbly blues file fol...
# 1550  Pocket chart features 10 seethrough plastic po...
# 4377  Simple Direct Understated Thank Notes Black Sc...
# 5113
# 1706  allinone math reference set includes place val...
# 3916  Spend Year Space awardwinning largeformat wall...
# 9643  little book contains fillintheblank lines desc...
# 1112  Eyecatching 50 x 32 reference piece home class...
# 9398  little book contains fillintheblank lines desc...
# 1958  sturdy pocket chart features 10 pockets fit le...
# 5286
# 8323  hasnt wandered blindly grocery store trying re...
# 5919  OOLY love creating products help people ages s...
# 4759  Productivity Planner combines productivity pri...
# 9124  Knock Knock independent maker clever gifts boo...
#
#                                           combined_text  \
# 1868  Scholastic Teachers Friend Schedule Cards Pock...
# 1340  Scholastic File Organizer Pocket Chart TF5104 ...
# 3119  Carson Dellosa 5239 KidDrawn Christian Faith S...
# 3395  MarkMyTime Digital Bookmark Reading Timer Neon...
# 5451  Freedom Journal Best Daily Planner Accomplish ...
# 7059  CarsonDellosa File Folders CDP136002 Office Pr...
# 1550  Standard Pocket Chart Office Products Office a...
# 4377  pretty simple cards quotThank Cardsquot 12 Car...
# 5113  Freedom Journal Best Daily Planner Accomplish ...
# 1706  Scholastic Primary Math Charts Bulletin Board ...
# 3916  Neck Traction Collar Men Women Cervical Brace ...
# 9643  Knock Knock Love Mom Fill Love Journal Office ...
# 1112  Rand McNally MSeries FullColor Laminated Unite...
# 9398  Knock Knock Love Mom Fill Love Journal Office ...
# 1958  Scholastic Classroom Resources File Organizer ...
# 5286  Freedom Journal Best Daily Planner Accomplish ...
# 8323  Knock Knock Pad Red Office Products Office amp...
# 5919  OOLY Yummy Yummy Scented Glitter Gel Pens 1321...
# 4759  Productivity Planner Daily Planner Non Dated 5...
# 9124  Knock Knock High Five Nifty Note Pad Office Pr...
#
#                                      combined_embedding
# 1868  [-0.026725624, 0.00227817, 0.028070852, -0.032...
# 1340  [0.0060373796, 0.0038241984, -0.016716043, -0....
# 3119  [-0.060244426, -0.03650533, 0.008916414, 0.003...
# 3395  [-0.066248976, -0.025308834, 0.005696673, 0.04...
# 5451  [-0.03452844, 0.071058184, 0.028710531, 0.0805...
# 7059  [-0.011596656, 0.0046337475, -0.013802588, 0.0...
# 1550  [-0.03116564, 0.021455582, -0.004495336, -0.02...
# 4377  [-0.05072979, 0.066627346, 0.019013071, 0.0749...
# 5113  [-0.03452844, 0.071058184, 0.028710531, 0.0805...
# 1706  [0.027112152, -0.04390265, -0.0042294986, -0.0...
# 3916  [-0.020963527, -0.020294044, 0.024254836, 0.06...
# 9643  [-0.14287941, 0.066391945, 0.058475886, 0.0382...
# 1112  [0.047321346, 0.018869342, 0.056916904, -0.013...
# 9398  [-0.14287941, 0.066391945, 0.058475886, 0.0382...
# 1958  [-0.017251115, 0.03228359, -0.02460217, -0.014...
# 5286  [-0.03452844, 0.071058184, 0.028710531, 0.0805...
# 8323  [-0.09554126, -0.010744167, 0.027027143, 0.004...
# 5919  [-0.06472299, -0.052756432, 0.073841885, -0.01...
# 4759  [-0.02326533, 0.0468504, 0.039011892, 0.062022...
# 9124  [-0.08560264, 0.019473752, 0.05254958, -0.0207...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Product_name         10000 non-null  object
#  1   category_for_rec     10000 non-null  object
#  2   description_for_rec  10000 non-null  object
#  3   combined_text        10000 non-null  object
#  4   combined_embedding   10000 non-null  object
# dtypes: object(5)
# memory usage: 390.8+ KB

# %%
df2.combined_embedding[0]
# Out:
# array([-1.13985658e-01,  2.96170972e-02,  2.20395047e-02,  1.28198704e-02,
#         3.35913268e-04,  2.03762064e-03,  1.04566537e-01,  3.95324789e-02,
#         3.63291777e-03,  1.43586588e-03,  5.99806979e-02,  4.42380346e-02,
#        -8.74844193e-03,  3.83620858e-02, -2.00432912e-03,  5.50881736e-02,
#         2.62357015e-02,  6.41684681e-02,  5.43782562e-02,  9.08802729e-03,
#         5.65564372e-02,  5.05657531e-02,  6.05862029e-02, -7.71827204e-03,
#        -3.28158997e-02,  1.20924011e-01, -2.05528997e-02, -1.44500554e-01,
#         1.27150456e-03, -5.79404943e-02,  1.79672372e-02,  8.07602555e-02,
#         6.75414205e-02,  5.05498238e-02,  4.71836179e-02,  2.55447384e-02,
#         8.65877196e-02,  2.16620881e-02,  3.92201096e-02,  8.00263211e-02,
#         8.73124693e-03, -3.34960967e-02, -2.30383556e-02, -4.29795682e-02,
#        -1.20390449e-02, -4.59842309e-02, -1.72692221e-02,  2.66106017e-02,
#         5.10983244e-02, -1.76471863e-02, -1.84013788e-02, -7.52899125e-02,
#        -4.58665602e-02,  9.83075704e-03, -5.80319799e-02, -2.69726142e-02,
#         4.20648977e-02,  3.56563367e-02,  2.06431616e-02, -2.19774712e-02,
#         2.52103191e-02,  1.32796010e-02, -6.06330410e-02,  1.44702010e-02,
#         7.81177729e-03,  2.88493652e-02, -2.66896300e-02,  9.08252597e-02,
#        -5.69303185e-02, -6.62932289e-04, -2.91808117e-02,  2.01243460e-02,
#        -1.94180012e-02,  5.88911921e-02,  4.75057960e-02,  4.24773097e-02,
#         6.56903386e-02, -7.77580664e-02,  5.01596518e-02, -2.89714225e-02,
#        -1.34301543e-01, -5.61918840e-02,  8.62445682e-03,  6.55620918e-02,
#        -3.63621325e-03,  3.04036518e-03, -1.33172201e-03, -1.87910907e-02,
#        -1.06039373e-02, -1.07058078e-01, -2.10805014e-02, -9.50579494e-02,
#         4.73622279e-03,  5.38453534e-02, -7.49981254e-02, -2.49332357e-02,
#        -4.31428142e-02, -1.78317968e-02, -4.36338745e-02,  2.88903923e-03,
#        -3.14998180e-02,  2.72692591e-02,  1.28171086e-01, -4.56890650e-03,
#        -7.57379318e-03, -2.66300403e-02, -4.46972735e-02, -4.15758379e-02,
#         6.85321018e-02,  6.07168861e-02, -4.69654799e-02, -2.34948210e-02,
#        -3.69587801e-02, -1.50216473e-02,  2.55096704e-02, -6.49214685e-02,
#        -7.61925727e-02,  4.67443764e-02,  6.44505257e-03,  7.06598014e-02,
#         1.27185704e-02,  4.87389565e-02, -9.07586068e-02, -4.02990393e-02,
#        -9.02772024e-02, -4.90060560e-02, -1.18165184e-02,  1.16674199e-32,
#         3.66041921e-02,  1.97475385e-02,  4.03268784e-02,  7.74183199e-02,
#         5.38874231e-02,  1.14160040e-02, -7.39799999e-03, -1.71846990e-03,
#         2.35519204e-02,  8.19986612e-02,  2.93233320e-02,  5.25824465e-02,
#        -7.84935802e-02,  7.11385906e-02,  1.45363733e-02, -4.22483049e-02,
#        -2.64696516e-02, -2.74983514e-03,  5.04119247e-02,  2.56325603e-02,
#        -2.91550662e-02, -2.45981682e-02,  1.11923134e-02, -3.97985801e-02,
#         2.64925659e-02, -6.78893849e-02,  4.08138940e-03,  7.26639875e-04,
#         1.40844718e-01,  4.64979410e-02, -2.74575166e-02, -7.58000612e-02,
#         2.55804248e-02, -8.89144186e-03, -1.42091021e-01, -1.81116425e-02,
#        -1.33279273e-02, -6.18228354e-02,  2.02931650e-02, -1.08210389e-02,
#        -1.75031535e-02, -4.61661033e-02,  4.74474467e-02,  4.06819955e-02,
#         4.81569255e-03, -2.52011660e-02,  8.69313926e-02,  5.23885898e-02,
#         5.61761744e-02,  5.93592320e-03, -6.51942417e-02,  4.01025219e-03,
#        -5.71116395e-02, -4.16283272e-02, -4.57547605e-02, -6.03296049e-02,
#         4.51413542e-02, -1.25521235e-02, -2.30083498e-03, -3.02263051e-02,
#         9.58255157e-02,  1.03042766e-01,  3.76882143e-02, -5.73948771e-02,
#         5.55540994e-02, -1.06806541e-02,  5.84452152e-02, -3.96360084e-02,
#         5.85807301e-02, -1.74334776e-02, -7.50463828e-02,  2.15775948e-02,
#         1.29032815e-02, -1.01796153e-03,  6.98358845e-03, -2.77598817e-02,
#         6.55619800e-02,  1.24011552e-02, -3.91006954e-02, -1.07767232e-01,
#         2.07807720e-02, -1.02902494e-01,  6.20571859e-02,  3.29639241e-02,
#         1.58183202e-02, -1.39646726e-02,  2.04712655e-02, -5.64871095e-02,
#        -7.26610348e-02, -1.56106055e-02, -3.43450229e-03,  2.14541834e-02,
#        -9.21943039e-03,  4.30431776e-02, -4.83293012e-02, -1.03517059e-32,
#         4.00914401e-02, -4.15491797e-02,  4.08710819e-03,  3.12955119e-02,
#         6.67699873e-02,  5.66453626e-03,  1.09273731e-03, -3.73561829e-02,
#        -3.88596021e-02,  5.68545144e-03, -4.97071855e-02, -4.01292779e-02,
#         5.91884479e-02, -1.80784333e-02,  9.82156396e-02,  5.67037612e-02,
#         3.41216028e-02,  5.31605817e-02,  1.38942255e-02, -3.50831524e-02,
#        -1.04517788e-02, -1.15974238e-02, -5.39743081e-02,  3.49486843e-02,
#        -6.14621788e-02, -4.48809005e-02, -5.17351255e-02, -8.74138847e-02,
#         2.25639134e-03,  4.51573431e-02, -2.57355068e-02, -4.54827324e-02,
#        -1.72919966e-02,  6.14265092e-02, -4.81048785e-02, -5.15084788e-02,
#        -7.14889094e-02, -2.91820839e-02,  1.37314536e-02, -1.32011361e-02,
#         5.69285192e-02, -7.97976851e-02, -1.89304389e-02,  5.54251000e-02,
#        -2.19359547e-02, -7.15496019e-02, -9.17707458e-02,  4.68683392e-02,
#         1.81475170e-02,  4.73695286e-02,  3.66816595e-02,  5.86518086e-02,
#        -6.66865185e-02, -8.01548138e-02, -6.99708834e-02,  1.29862815e-01,
#        -4.73343767e-02, -6.55445233e-02,  2.89654341e-02,  8.56421795e-03,
#        -1.51969371e-02,  2.85760257e-02, -5.05030379e-02, -2.95778625e-02,
#         3.39067280e-02, -1.60229057e-02, -6.75779805e-02,  9.98630421e-04,
#        -3.71926203e-02,  2.01191641e-02,  9.58879963e-02,  1.33021966e-01,
#         2.52020154e-02, -1.43637657e-01,  3.97447124e-02,  9.16142687e-02,
#        -3.86924408e-02, -6.65122569e-02,  2.15526316e-02,  3.68325599e-02,
#         4.79141176e-02, -3.20857670e-03,  2.06705499e-02,  8.53488371e-02,
#        -1.05491141e-02,  2.99132452e-03,  3.73105668e-02,  6.90969899e-02,
#        -2.58957818e-02,  9.07459483e-03, -6.89197192e-03,  1.92672983e-02,
#         2.23028529e-02,  7.60992467e-02,  8.74938890e-02, -3.35211574e-08,
#        -4.27009724e-02, -1.66381914e-02,  2.58520208e-02, -4.32687663e-02,
#         8.03483501e-02, -7.34977126e-02,  6.43695705e-03,  3.76160108e-02,
#         4.79861349e-03,  6.32406399e-02, -3.12639065e-02, -8.48398954e-02,
#        -3.94082032e-02,  2.94069611e-02,  3.78450938e-02,  4.23613423e-03,
#         5.30049838e-02, -5.79071827e-02, -2.19649319e-02, -2.12352965e-02,
#         1.03725210e-01, -5.62358797e-02,  6.22268766e-02,  6.20450005e-02,
#        -1.75724656e-03, -4.46551107e-02, -8.80590007e-02,  2.74033695e-02,
#        -2.61768214e-02,  1.17937334e-01,  2.80204564e-02,  2.00692322e-02,
#        -5.55946939e-02, -6.73415214e-02, -3.11463582e-03, -5.18175438e-02,
#        -2.72440463e-02, -6.60264269e-02, -9.02365800e-03,  7.19253644e-02,
#         5.77992424e-02, -8.52914751e-02,  4.36734781e-02,  3.31799090e-02,
#        -1.34222088e-02, -4.54084799e-02,  9.81976688e-02, -1.10290468e-01,
#        -2.67035421e-02,  6.18140493e-03, -4.52387482e-02, -2.65022516e-02,
#         3.71246636e-02, -5.75370491e-02,  3.04793995e-02, -5.39511628e-03,
#        -6.10409304e-02, -1.30716264e-02,  1.60520636e-02,  4.45541479e-02,
#        -8.63959268e-02, -7.13801011e-03,  2.71458626e-02, -8.11121985e-03],
#       dtype=float32)

# %%
#df2.to_csv('data_with_embeddings.csv',index=False)

# %% [markdown]
# # Cosine Similarity
# - Cosine similarity is calculated between the input text and the embeddings of all products in the dataset.
# - The most similar products are identified based on the cosine similarity scores.
# - The top similar products are retrieved and displayed.

# %%
from sentence_transformers import util # cosine similarity

# %%
def get_similar_products(combined_input, df, top_n=2):
    combined_embedding = model.encode(combined_input)
    
    similarities = util.pytorch_cos_sim(combined_embedding, df2['combined_embedding'])
    
    print(similarities)
    
    similar_indices = similarities.argsort(descending= True,axis = 1)[0][:top_n]
    print(similar_indices)
    
    similar_items_df = df2.iloc[similar_indices][['Product_name','category_for_rec','description_for_rec']]
    #print(similar_items)
    return similar_items_df

# %%
product_info_to_search = "Colorful Chalkboard"

similar_items = get_similar_products(product_info_to_search,df2)
similar_items
# Out:
# tensor([[0.2228, 0.2228, 0.2228,  ..., 0.2378, 0.2378, 0.2378]])
# tensor([7102, 7114])
# C:\Users\prabh\anaconda3\lib\site-packages\sentence_transformers\util.py:39: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\torch\csrc\utils\tensor_new.cpp:264.)
#   b = torch.tensor(b)
#                         Product_name  \
# 7102  Colorful Chalkboard EZ Letters
# 7114  Colorful Chalkboard EZ Letters
#
#                                        category_for_rec  \
# 7102  Office Products Office School Supplies Educati...
# 7114  Office Products Office School Supplies Educati...
#
#                                     description_for_rec
# 7102  DIVEasily create eyecatching messages contempo...
# 7114  DIVEasily create eyecatching messages contempo...

# %%
print(product_info_to_search)
print("\nSimilar Products:")
for idx,row in similar_items.iterrows():
    print(f"Product : {row['Product_name']}")
# Out:
# Colorful Chalkboard
#
# Similar Products:
# Product : Colorful Chalkboard EZ Letters
# Product : Colorful Chalkboard EZ Letters

# %%
product_info_to_search = input("Enter Keywords : ")

similar_items = get_similar_products(product_info_to_search,df2)
print(product_info_to_search)
print("\nSimilar Products:")
for idx,row in similar_items.iterrows():
    print(f"Product : {row['Product_name']}")
similar_items
# Out:
# Enter Keywords : notebook
# tensor([[0.3006, 0.3006, 0.3006,  ..., 0.2912, 0.2912, 0.2912]])
# tensor([3600, 3586])
# notebook
#
# Similar Products:
# Product : Scientific Notebook Laboratory Notebook 192 numbered pages black hardcover 2001HC
# Product : Scientific Notebook Laboratory Notebook 192 numbered pages black hardcover 2001HC
#                                            Product_name  \
# 3600  Scientific Notebook Laboratory Notebook 192 nu...
# 3586  Scientific Notebook Laboratory Notebook 192 nu...
#
#                                        category_for_rec  \
# 3600  Office Products Office School Supplies Paper N...
# 3586  Office Products Office School Supplies Paper N...
#
#                                     description_for_rec
# 3600  Bound laboratory notebook archival quality sec...
# 3586  Bound laboratory notebook archival quality sec...

# %% [markdown]
# **This project aims to provide users with personalized and relevant product recommendations based on textual input, thereby enhancing their shopping experience and increasing engagement with the platform.**
